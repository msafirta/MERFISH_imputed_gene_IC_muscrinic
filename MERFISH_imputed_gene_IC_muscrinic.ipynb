# %% [markdown]
# # Allen Brain Cell Atlas Use Case
# This notebook is an example of how to use data from the Allen Brain Cell (ABC) Atas. Code for this notebook comes from [ABC Atlas Access](https://alleninstitute.github.io/abc_atlas_access/intro.html), which features in depth tutorials on ABC Atlas scRNAseq and MERFISH datasets. Use ABC Atlas Access to learn more about each of the datasets. The text following '#' are comments and/or indicate where the code can be edited to look at different brain regions, cell types, etc. This notebook is intended to be used in Google Colab.
# ## Use Case Description
# This code aims to determine muscrinic cells in the inferior colliculus (IC). Using the ABC Atlas, they are looking at spatial transcriptomic mouse data— their genes of interest were not in the orginal 500-gene panel, however, they find their genes in the imputed gene dataset (from scRNAseq data). This dataset is titled "MERFISH-C57BL6J-638850 with Imputed Genes + Reconstructed Coordinates." [Here](https://knowledge.brain-map.org/abcatlas#%2BCAIAuBshTBwIjRkZGRkZGAAMABkdFTkUABwAIAgAACFZGT0ZZUEZRR1JLVURRVVozRkYACUxWREJKQVc4Qkk1WVNTMVFVQkcACgALAVRMT0tXQ0w5NVJVMDNEOVBFVEcAAjczR1ZURFhERUdFMjdNMlhKTVQAAwEEAQACIzAwMDAwMAADyAEABQEBAiMwMDAwMDAAA8gBAAAAAgEA) are the cells and genes they are studying in the ABC Atlas.
#
# Goal: plot gene expression of imputed genes Chrm1, Chrm2, Chrm3, Chrm4, and Chrm5 in glutamatergic neurons in IC.

# %%
# Install s3fs package
# !apt install s3fs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   s3fs
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 297 kB of archives.
# After this operation, 794 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 s3fs amd64 1.90-1 [297 kB]
# Fetched 297 kB in 0s (2,327 kB/s)
# Selecting previously unselected package s3fs.
# (Reading database ... 126109 files and directories currently installed.)
# Preparing to unpack .../archives/s3fs_1.90-1_amd64.deb ...
# Unpacking s3fs (1.90-1) ...
# Setting up s3fs (1.90-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Make directory to mount s3 data into
# !mkdir -p /data/abc_atlas

# %%
# Mount the s3 bucket using s3fs-fuse
# !s3fs -o public_bucket=1 -o default_acl=public-read -o endpoint="us-west-2" allen-brain-cell-atlas /data/abc_atlas

# %%
# Check that it's mounted
# !ls -ltrh /data/abc_atlas
# Out:
# total 35K
# drwxr-x--- 1 root root   0 Dec 31  1969 releases
# drwxr-x--- 1 root root   0 Dec 31  1969 metadata
# drwxr-x--- 1 root root   0 Dec 31  1969 mapmycells
# drwxr-x--- 1 root root   0 Dec 31  1969 image_volumes
# drwxr-x--- 1 root root   0 Dec 31  1969 expression_matrices
# -rw-r----- 1 root root 32K Jun  7  2023 index.html

# %%
# Install abc_atlas_access
# %pip install "abc_atlas_access[notebooks] @ git+https://github.com/alleninstitute/abc_atlas_access.git"
# Out:
# Collecting abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git (from abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Cloning https://github.com/alleninstitute/abc_atlas_access.git to /tmp/pip-install-e0b97aet/abc-atlas-access_6470459ebc064f2aa5b71c836cd04787
#   Running command git clone --filter=blob:none --quiet https://github.com/alleninstitute/abc_atlas_access.git /tmp/pip-install-e0b97aet/abc-atlas-access_6470459ebc064f2aa5b71c836cd04787
#   Resolved https://github.com/alleninstitute/abc_atlas_access.git to commit 398c9cc557a4b1e75dc68dd3d4965d3ed50367b2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anndata (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading anndata-0.11.4-py3-none-any.whl.metadata (9.3 kB)
# Collecting boto3 (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading boto3-1.38.23-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (4.67.1)
# Collecting geojson (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.15.3)
# Collecting simpleitk (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading simpleitk-2.5.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.7 in /usr/local/lib/python3.11/dist-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.13.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2025.2)
# Collecting botocore<1.39.0,>=1.38.23 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading botocore-1.38.23-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (0.4.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.23->boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.17.0)
# Downloading anndata-0.11.4-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 11.9 MB/s eta 0:00:00
# Downloading boto3-1.38.23-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 12.7 MB/s eta 0:00:00
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading simpleitk-2.5.0-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 13.8 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 5.3 MB/s eta 0:00:00
# Downloading botocore-1.38.23-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 82.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 5.9 MB/s eta 0:00:00
# Building wheels for collected packages: abc_atlas_access
#   Building wheel for abc_atlas_access (pyproject.toml) ... done
#   Created wheel for abc_atlas_access: filename=abc_atlas_access-0.7.0-py3-none-any.whl size=21660 sha256=d8545bb843a6250a88f97f245c6cdfec839be8670010a13fdc6de8cca58d4311
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ys4y77zh/wheels/2d/d9/f3/f2db0241b1dee95bfc46efed11e346b267a4dade369a8acc83
# Successfully built abc_atlas_access
# Installing collected packages: simpleitk, jmespath, geojson, array-api-compat, botocore, s3transfer, anndata, boto3, abc_atlas_access
# Successfully installed abc_atlas_access-0.7.0 anndata-0.11.4 array-api-compat-1.12.0 boto3-1.38.23 botocore-1.38.23 geojson-3.2.0 jmespath-1.0.1 s3transfer-0.13.0 simpleitk-2.5.0

# %%
from pathlib import Path
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
download_base = Path('/data/abc_atlas')
abc_cache = AbcProjectCache.from_local_cache(download_base)

abc_cache.current_manifest
# Out:
# /usr/local/lib/python3.11/dist-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:470: MissingLocalManifestWarning: This cache directory appears to contain data files, but it has no record of what those files are. Unless running as a LocalCache, files will be re-downloaded.
#   warnings.warn(msg, MissingLocalManifestWarning)
# /usr/local/lib/python3.11/dist-packages/abc_atlas_access/abc_atlas_cache/cloud_cache.py:1373: ReadOnlyLocalCacheWarning: LocalCache is a read only directory and cannot
#                 save the last used manifest.
#                 Current Manifest: releases/20250531/manifest.json
#   warnings.warn(
# 'releases/20250531/manifest.json'

# %%
abc_cache.list_directories
# Out:
# ['ASAP-PMDBS-10X',
#  'ASAP-PMDBS-taxonomy',
#  'Allen-CCF-2020',
#  'HMBA-10xMultiome-BG',
#  'HMBA-10xMultiome-BG-Aligned',
#  'HMBA-BG-taxonomy-CCN20250428',
#  'MERFISH-C57BL6J-638850',
#  'MERFISH-C57BL6J-638850-CCF',
#  'MERFISH-C57BL6J-638850-imputed',
#  'MERFISH-C57BL6J-638850-sections',
#  'SEAAD',
#  'SEAAD-taxonomy',
#  'WHB-10Xv3',
#  'WHB-taxonomy',
#  'WMB-10X',
#  'WMB-10XMulti',
#  'WMB-10Xv2',
#  'WMB-10Xv3',
#  'WMB-neighborhoods',
#  'WMB-taxonomy',
#  'Zeng-Aging-Mouse-10Xv3',
#  'Zeng-Aging-Mouse-WMB-taxonomy',
#  'Zhuang-ABCA-1',
#  'Zhuang-ABCA-1-CCF',
#  'Zhuang-ABCA-2',
#  'Zhuang-ABCA-2-CCF',
#  'Zhuang-ABCA-3',
#  'Zhuang-ABCA-3-CCF',
#  'Zhuang-ABCA-4',
#  'Zhuang-ABCA-4-CCF']

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl

from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %%
# Edit the notebook from here onward
# Load metadata for cell dataset
cell = abc_cache.get_metadata_dataframe(
    directory='MERFISH-C57BL6J-638850', # To change dataset, enter the directory name from the list above (abc_cache.list_directories). If using imputed genes, use 'MERFISH-C57BL6J-638850'
    file_name='cell_metadata_with_cluster_annotation',
    dtype={"cell_label": str,
           "neurotransmitter": str}
)
cell.set_index('cell_label', inplace=True)

# %%
# filter cells for neurotransmitter type and show first 5 cells in table
NT_cells = cell[cell['neurotransmitter'] == 'GABA'] # 'GABA' change neurotransmitter here
NT_cells.head(5)
# Out:
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344101400358-4   C57BL6J-638850.33           3155
# 1017092617102560597     C57BL6J-638850.38           1258
# 1104095349102280703     C57BL6J-638850.52           1258
# 1017155956100650356     C57BL6J-638850.50           1258
# 1104095349102440200-3   C57BL6J-638850.52           1258
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344101400358-4                   0.504776       C57BL6J-638850
# 1017092617102560597                     0.542498       C57BL6J-638850
# 1104095349102280703                     0.527005       C57BL6J-638850
# 1017155956100650356                     0.691000       C57BL6J-638850
# 1104095349102440200-3                   0.669169       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344101400358-4  C57BL6J-638850          wt/wt         M  4.441577
# 1017092617102560597    C57BL6J-638850          wt/wt         M  8.175661
# 1104095349102280703    C57BL6J-638850          wt/wt         M  7.644348
# 1017155956100650356    C57BL6J-638850          wt/wt         M  7.889727
# 1104095349102440200-3  C57BL6J-638850          wt/wt         M  7.806380
#
#                               y    z neurotransmitter           class  \
# cell_label
# 1018093344101400358-4  6.464796  5.8             GABA      20 MB GABA
# 1017092617102560597    6.082802  6.8             GABA  05 OB-IMN GABA
# 1104095349102280703    7.696379  9.8             GABA  05 OB-IMN GABA
# 1017155956100650356    7.462066  9.4             GABA  05 OB-IMN GABA
# 1104095349102440200-3  7.547507  9.8             GABA  05 OB-IMN GABA
#
#                                        subclass                    supertype  \
# cell_label
# 1018093344101400358-4         197 SNr Six3 Gaba         0806 SNr Six3 Gaba_1
# 1017092617102560597    039 OB Meis2 Thsd7b Gaba  0143 OB Meis2 Thsd7b Gaba_1
# 1104095349102280703    039 OB Meis2 Thsd7b Gaba  0143 OB Meis2 Thsd7b Gaba_1
# 1017155956100650356    039 OB Meis2 Thsd7b Gaba  0143 OB Meis2 Thsd7b Gaba_1
# 1104095349102440200-3  039 OB Meis2 Thsd7b Gaba  0143 OB Meis2 Thsd7b Gaba_1
#
#                                            cluster neurotransmitter_color  \
# cell_label
# 1018093344101400358-4         3464 SNr Six3 Gaba_1                #FF3358
# 1017092617102560597    0518 OB Meis2 Thsd7b Gaba_1                #FF3358
# 1104095349102280703    0518 OB Meis2 Thsd7b Gaba_1                #FF3358
# 1017155956100650356    0518 OB Meis2 Thsd7b Gaba_1                #FF3358
# 1104095349102440200-3  0518 OB Meis2 Thsd7b Gaba_1                #FF3358
#
#                       class_color subclass_color supertype_color cluster_color
# cell_label
# 1018093344101400358-4     #9EF01A        #7A5C99         #2E995C       #62CC00
# 1017092617102560597       #1b4332        #FF99F7         #9F00CC       #994945
# 1104095349102280703       #1b4332        #FF99F7         #9F00CC       #994945
# 1017155956100650356       #1b4332        #FF99F7         #9F00CC       #994945
# 1104095349102440200-3     #1b4332        #FF99F7         #9F00CC       #994945

# %%
# get reconstructed x,y,z coordinates for each cell — this is needed anatomical regions. Show first 5 cells in table
reconstructed_coords = abc_cache.get_metadata_dataframe(
    directory='MERFISH-C57BL6J-638850-CCF',
    file_name='reconstructed_coordinates',
    dtype={"cell_label": str}
)
reconstructed_coords.rename(columns={'x': 'x_reconstructed',
                                     'y': 'y_reconstructed',
                                     'z': 'z_reconstructed'}, # Loads 3D Constructed spatial coordinates for cell
                            inplace=True)
reconstructed_coords.set_index('cell_label', inplace=True)
reconstructed_coords.head(5)
# Out:
#                      x_reconstructed  y_reconstructed  z_reconstructed  \
# cell_label
# 1019171911101460569         7.143894         7.890964              0.8
# 1019171911101550321         4.188673         7.962972              0.8
# 1019171911100841066         6.859447         5.908534              0.8
# 1019171911101400425         3.952014         7.564086              0.8
# 1019171911101380264         2.803546         7.221688              0.8
#
#                      parcellation_index
# cell_label
# 1019171911101460569                 945
# 1019171911101550321                 945
# 1019171911100841066                 893
# 1019171911101400425                 842
# 1019171911101380264                   0

# %%
# add coordinates for each cell to table and show first 5 cells in table
cell_joined = NT_cells.join(reconstructed_coords, how='inner')
cell_joined.head(5) # Merges cell metadata with spatial coordinates
# Out:
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344101400358-4   C57BL6J-638850.33           3155
# 1017092617102560597     C57BL6J-638850.38           1258
# 1104095349102280703     C57BL6J-638850.52           1258
# 1017155956100650356     C57BL6J-638850.50           1258
# 1104095349102440200-3   C57BL6J-638850.52           1258
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344101400358-4                   0.504776       C57BL6J-638850
# 1017092617102560597                     0.542498       C57BL6J-638850
# 1104095349102280703                     0.527005       C57BL6J-638850
# 1017155956100650356                     0.691000       C57BL6J-638850
# 1104095349102440200-3                   0.669169       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344101400358-4  C57BL6J-638850          wt/wt         M  4.441577
# 1017092617102560597    C57BL6J-638850          wt/wt         M  8.175661
# 1104095349102280703    C57BL6J-638850          wt/wt         M  7.644348
# 1017155956100650356    C57BL6J-638850          wt/wt         M  7.889727
# 1104095349102440200-3  C57BL6J-638850          wt/wt         M  7.806380
#
#                               y    z  ...                      cluster  \
# cell_label                            ...
# 1018093344101400358-4  6.464796  5.8  ...         3464 SNr Six3 Gaba_1
# 1017092617102560597    6.082802  6.8  ...  0518 OB Meis2 Thsd7b Gaba_1
# 1104095349102280703    7.696379  9.8  ...  0518 OB Meis2 Thsd7b Gaba_1
# 1017155956100650356    7.462066  9.4  ...  0518 OB Meis2 Thsd7b Gaba_1
# 1104095349102440200-3  7.547507  9.8  ...  0518 OB Meis2 Thsd7b Gaba_1
#
#                       neurotransmitter_color class_color subclass_color  \
# cell_label
# 1018093344101400358-4                #FF3358     #9EF01A        #7A5C99
# 1017092617102560597                  #FF3358     #1b4332        #FF99F7
# 1104095349102280703                  #FF3358     #1b4332        #FF99F7
# 1017155956100650356                  #FF3358     #1b4332        #FF99F7
# 1104095349102440200-3                #FF3358     #1b4332        #FF99F7
#
#                       supertype_color cluster_color x_reconstructed  \
# cell_label
# 1018093344101400358-4         #2E995C       #62CC00        4.446538
# 1017092617102560597           #9F00CC       #994945        8.093125
# 1104095349102280703           #9F00CC       #994945        7.596676
# 1017155956100650356           #9F00CC       #994945        7.906556
# 1104095349102440200-3         #9F00CC       #994945        7.738014
#
#                       y_reconstructed z_reconstructed parcellation_index
# cell_label
# 1018093344101400358-4        6.117442             5.8                687
# 1017092617102560597          6.110577             6.8                  5
# 1104095349102280703          7.463540             9.8                688
# 1017155956100650356          7.408553             9.4                951
# 1104095349102440200-3        7.334997             9.8                951
#
# [5 rows x 24 columns]

# %%
# get anatomical regions and show first 5 cells in table
parcellation_annotation = abc_cache.get_metadata_dataframe(directory='Allen-CCF-2020',
                                                           file_name='parcellation_to_parcellation_term_membership_acronym')
parcellation_annotation.set_index('parcellation_index', inplace=True)
parcellation_annotation.columns = ['parcellation_%s'% x for x in  parcellation_annotation.columns]
parcellation_annotation.head(5)
# Out:
#                    parcellation_organ parcellation_category  \
# parcellation_index
# 0                          unassigned            unassigned
# 1                               brain                  grey
# 2                               brain                  grey
# 5                               brain          fiber tracts
# 6                               brain                  grey
#
#                    parcellation_division parcellation_structure  \
# parcellation_index
# 0                             unassigned             unassigned
# 1                                     HY                    TMv
# 2                              Isocortex                  SSp-m
# 5                                   lfbs                    cst
# 6                                      P                    PSV
#
#                    parcellation_substructure
# parcellation_index
# 0                                 unassigned
# 1                                        TMv
# 2                                    SSp-m6b
# 5                                        int
# 6                                        PSV

# %%
# Load and format color annotations for anatomical regions

#Load a metadata file that maps brain region (parcellation index) to a color
parcellation_color = abc_cache.get_metadata_dataframe(directory='Allen-CCF-2020',
                                                      file_name='parcellation_to_parcellation_term_membership_color')
parcellation_color.set_index('parcellation_index', inplace=True) #Set 'parcellation_index' as row index name
parcellation_color.columns = ['parcellation_%s'% x for x in  parcellation_color.columns] #Rename columns
parcellation_color.head(5) #Show first 5 rows
# Out:
#                    parcellation_organ_color parcellation_category_color  \
# parcellation_index
# 0                                   #000000                     #000000
# 1                                   #FFFFFF                     #BFDAE3
# 2                                   #FFFFFF                     #BFDAE3
# 5                                   #FFFFFF                     #CCCCCC
# 6                                   #FFFFFF                     #BFDAE3
#
#                    parcellation_division_color parcellation_structure_color  \
# parcellation_index
# 0                                      #000000                      #000000
# 1                                      #E64438                      #FF4C3E
# 2                                      #70FF71                      #188064
# 5                                      #CCCCCC                      #CCCCCC
# 6                                      #FF9B88                      #FFAE6F
#
#                    parcellation_substructure_color
# parcellation_index
# 0                                          #000000
# 1                                          #FF4C3E
# 2                                          #188064
# 5                                          #CCCCCC
# 6                                          #FFAE6F

# %%
# add anatomical regions to table and show first 5 cells in table
cell_joined = cell_joined.join(parcellation_annotation, on='parcellation_index')
cell_joined.head(5)
# Out:
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344101400358-4   C57BL6J-638850.33           3155
# 1017092617102560597     C57BL6J-638850.38           1258
# 1104095349102280703     C57BL6J-638850.52           1258
# 1017155956100650356     C57BL6J-638850.50           1258
# 1104095349102440200-3   C57BL6J-638850.52           1258
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344101400358-4                   0.504776       C57BL6J-638850
# 1017092617102560597                     0.542498       C57BL6J-638850
# 1104095349102280703                     0.527005       C57BL6J-638850
# 1017155956100650356                     0.691000       C57BL6J-638850
# 1104095349102440200-3                   0.669169       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344101400358-4  C57BL6J-638850          wt/wt         M  4.441577
# 1017092617102560597    C57BL6J-638850          wt/wt         M  8.175661
# 1104095349102280703    C57BL6J-638850          wt/wt         M  7.644348
# 1017155956100650356    C57BL6J-638850          wt/wt         M  7.889727
# 1104095349102440200-3  C57BL6J-638850          wt/wt         M  7.806380
#
#                               y    z  ... cluster_color x_reconstructed  \
# cell_label                            ...
# 1018093344101400358-4  6.464796  5.8  ...       #62CC00        4.446538
# 1017092617102560597    6.082802  6.8  ...       #994945        8.093125
# 1104095349102280703    7.696379  9.8  ...       #994945        7.596676
# 1017155956100650356    7.462066  9.4  ...       #994945        7.906556
# 1104095349102440200-3  7.547507  9.8  ...       #994945        7.738014
#
#                       y_reconstructed z_reconstructed parcellation_index  \
# cell_label
# 1018093344101400358-4        6.117442             5.8                687
# 1017092617102560597          6.110577             6.8                  5
# 1104095349102280703          7.463540             9.8                688
# 1017155956100650356          7.408553             9.4                951
# 1104095349102440200-3        7.334997             9.8                951
#
#                       parcellation_organ parcellation_category  \
# cell_label
# 1018093344101400358-4              brain          fiber tracts
# 1017092617102560597                brain          fiber tracts
# 1104095349102280703                brain                  grey
# 1017155956100650356                brain                  grey
# 1104095349102440200-3              brain                  grey
#
#                       parcellation_division parcellation_structure  \
# cell_label
# 1018093344101400358-4                    cm                    drt
# 1017092617102560597                    lfbs                    cst
# 1104095349102280703                     OLF         OLF-unassigned
# 1017155956100650356                     OLF                    PIR
# 1104095349102440200-3                   OLF                    PIR
#
#                       parcellation_substructure
# cell_label
# 1018093344101400358-4                        ml
# 1017092617102560597                         int
# 1104095349102280703              OLF-unassigned
# 1017155956100650356                         PIR
# 1104095349102440200-3                       PIR
#
# [5 rows x 29 columns]

# %%
# Determine how brain region of interest is labeled
structures = cell_joined["parcellation_structure"].unique()
for s in sorted(structures):
    print(s)
# Out:
# AAA
# ACAd
# ACAv
# ACB
# ADP
# AHN
# AId
# AIp
# AIv
# AM
# AMB
# AN
# AOB
# AON
# AP
# APN
# APr
# AQ
# ARH
# ASO
# AT
# AUDd
# AUDp
# AUDpo
# AUDv
# AV
# AVP
# AVPV
# B
# BA
# BLA
# BMA
# BST
# CA1
# CA2
# CA3
# CB-unassigned
# CEA
# CENT
# CL
# CLA
# CLI
# COAa
# COAp
# COPY
# CP
# CS
# CTXsp-unassigned
# CU
# CUL
# CUN
# DCO
# DEC
# DG
# DMH
# DN
# DP
# DR
# DT
# DTN
# ECT
# ENTl
# ENTm
# EPd
# EPv
# EW
# Eth
# FC
# FL
# FN
# FOTU
# FRP
# FS
# GPe
# GPi
# GRN
# GU
# HATA
# HPF-unassigned
# HY-unassigned
# IA
# IAM
# IC
# ICB
# IF
# IG
# IGL
# III
# IIIn
# IIn
# ILA
# IMD
# IP
# IPN
# IRN
# IV
# IVn
# In
# IntG
# LA
# LAV
# LD
# LDT
# LGd
# LGv
# LH
# LHA
# LING
# LM
# LP
# LPO
# LRN
# LSc
# LSr
# LSv
# LT
# MA
# MA3
# MB-unassigned
# MD
# ME
# MEA
# MEPO
# MG
# MH
# MM
# MOB
# MOp
# MOs
# MPN
# MPO
# MPT
# MRN
# MS
# MT
# MV
# MY-unassigned
# NB
# NDB
# NI
# NLL
# NLOT
# NOD
# NOT
# NPC
# NTB
# NTS
# OLF-unassigned
# OP
# ORBl
# ORBm
# ORBvl
# OT
# OV
# P-unassigned
# PA
# PAA
# PAG
# PAL-unassigned
# PAR
# PARN
# PB
# PBG
# PCG
# PCN
# PD
# PDTg
# PERI
# PF
# PFL
# PG
# PGRNd
# PGRNl
# PH
# PIL
# PIR
# PL
# PMv
# PN
# PO
# POL
# POST
# PP
# PPN
# PPT
# PPY
# PR
# PRE
# PRM
# PRNc
# PRNr
# PRP
# PS
# PST
# PSTN
# PSV
# PT
# PVH
# PVHd
# PVT
# PVa
# PVi
# PVp
# PVpo
# PYR
# Pa4
# Pa5
# PeF
# PoT
# ProS
# RCH
# RE
# RL
# RM
# RN
# RPA
# RPF
# RPO
# RR
# RSPagl
# RSPd
# RSPv
# RT
# SAG
# SBPV
# SCH
# SCO
# SCm
# SCs
# SEZ
# SF
# SFO
# SG
# SGN
# SH
# SI
# SIM
# SLC
# SLD
# SMT
# SNc
# SNr
# SO
# SOC
# SPA
# SPFm
# SPFp
# SPIV
# SPVI
# SPVO
# SSp-bfd
# SSp-ll
# SSp-m
# SSp-n
# SSp-tr
# SSp-ul
# SSp-un
# SSs
# STN
# STR-unassigned
# SUB
# SUM
# SUT
# SUV
# SubG
# TEa
# TH-unassigned
# TMv
# TR
# TRN
# TRS
# TT
# TU
# UVU
# V3-unassigned
# V4-unassigned
# V4r
# VAL
# VCO
# VIIIn
# VISC
# VISa
# VISal
# VISam
# VISl
# VISli
# VISp
# VISpl
# VISpm
# VISpor
# VISrl
# VL-unassigned
# VLPO
# VM
# VMH
# VMPO
# VPL
# VPLpc
# VPM
# VPMpc
# VTA
# VTN
# VeCB
# Vn
# Xi
# ZI
# arb
# brain-unassigned
# cbc
# cbp
# cc
# chpl
# cst
# drt
# epsc
# fiber tracts-unassigned
# lfbst
# mfbc
# mfsbshy
# rust
# scwm-unassigned
# tsp
# unassigned
# y

# %%
# filter for cells in anatomical division and show first 5 cells in table
cell_joined[cell_joined["parcellation_structure"]== 'IC']
# 'IC' change anatomical division here, 'parcellation_structure' change anatomical level here
# from ABC Atlas, anatomical division = parcellation_division, anatomical structure = parcellation_structure, anatomical substructure = parcellation_substructure
cell_joined.head(5)
# Out:
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344101400358-4   C57BL6J-638850.33           3155
# 1017092617102560597     C57BL6J-638850.38           1258
# 1104095349102280703     C57BL6J-638850.52           1258
# 1017155956100650356     C57BL6J-638850.50           1258
# 1104095349102440200-3   C57BL6J-638850.52           1258
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344101400358-4                   0.504776       C57BL6J-638850
# 1017092617102560597                     0.542498       C57BL6J-638850
# 1104095349102280703                     0.527005       C57BL6J-638850
# 1017155956100650356                     0.691000       C57BL6J-638850
# 1104095349102440200-3                   0.669169       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344101400358-4  C57BL6J-638850          wt/wt         M  4.441577
# 1017092617102560597    C57BL6J-638850          wt/wt         M  8.175661
# 1104095349102280703    C57BL6J-638850          wt/wt         M  7.644348
# 1017155956100650356    C57BL6J-638850          wt/wt         M  7.889727
# 1104095349102440200-3  C57BL6J-638850          wt/wt         M  7.806380
#
#                               y    z  ... cluster_color x_reconstructed  \
# cell_label                            ...
# 1018093344101400358-4  6.464796  5.8  ...       #62CC00        4.446538
# 1017092617102560597    6.082802  6.8  ...       #994945        8.093125
# 1104095349102280703    7.696379  9.8  ...       #994945        7.596676
# 1017155956100650356    7.462066  9.4  ...       #994945        7.906556
# 1104095349102440200-3  7.547507  9.8  ...       #994945        7.738014
#
#                       y_reconstructed z_reconstructed parcellation_index  \
# cell_label
# 1018093344101400358-4        6.117442             5.8                687
# 1017092617102560597          6.110577             6.8                  5
# 1104095349102280703          7.463540             9.8                688
# 1017155956100650356          7.408553             9.4                951
# 1104095349102440200-3        7.334997             9.8                951
#
#                       parcellation_organ parcellation_category  \
# cell_label
# 1018093344101400358-4              brain          fiber tracts
# 1017092617102560597                brain          fiber tracts
# 1104095349102280703                brain                  grey
# 1017155956100650356                brain                  grey
# 1104095349102440200-3              brain                  grey
#
#                       parcellation_division parcellation_structure  \
# cell_label
# 1018093344101400358-4                    cm                    drt
# 1017092617102560597                    lfbs                    cst
# 1104095349102280703                     OLF         OLF-unassigned
# 1017155956100650356                     OLF                    PIR
# 1104095349102440200-3                   OLF                    PIR
#
#                       parcellation_substructure
# cell_label
# 1018093344101400358-4                        ml
# 1017092617102560597                         int
# 1104095349102280703              OLF-unassigned
# 1017155956100650356                         PIR
# 1104095349102440200-3                       PIR
#
# [5 rows x 29 columns]

# %%
# get gene expression values from cell dataset
imputed_h5ad_path = abc_cache.get_data_path('MERFISH-C57BL6J-638850-imputed', 'C57BL6J-638850-imputed/log2')
# change cell dataset here.
adata = anndata.read_h5ad(imputed_h5ad_path, backed='r')
gene_list = ['Chrm1', 'Chrm2', 'Chrm3', 'Chrm4', 'Chrm5'] # edit genes here

# %%
# get ensemble IDs of genes of interest
pred = [x in gene_list for x in adata.var.gene_symbol]
gene_filtered = adata.var[pred]
gene_filtered
# Out:
#                    gene_symbol
# gene_identifier
# ENSMUSG00000046159       Chrm3
# ENSMUSG00000045613       Chrm2
# ENSMUSG00000032773       Chrm1
# ENSMUSG00000074939       Chrm5

# %%
# get gene expression values for genes of interest and show first 5 cells in table
gene_subset = adata[:, gene_filtered.index].to_df()
adata.file.close()
del adata

gene_subset.rename(columns=gene_filtered.to_dict()['gene_symbol'], inplace=True)
gene_subset.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# gene_identifier            Chrm3     Chrm2     Chrm1  Chrm5
# cell_label
# 1104095349100540743-1  10.109375  6.824219  6.687500    0.0
# 1018093345100600265    10.125000  6.777344  6.695312    0.0
# 1018135614102090183    10.109375  6.582031  6.781250    0.0
# 1104095348100570634    10.109375  6.875000  6.695312    0.0
# 1018122109102452991    10.132812  7.062500  6.785156    0.0

# %%
# add genes of interest to cell table
genes_of_interest = cell_joined.join(gene_subset, on='cell_label', how='inner') #merges gene expression values into cell metadata

# %%
# filter cell table for anatomical region
cell_table = genes_of_interest[genes_of_interest["parcellation_structure"]== 'IC']
# 'IC' change anatomical region here, 'parcellation_structure' change anatomical level here

# %%
# show all metadata for first 5 cells
cell_table.head(5)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344101450289-1   C57BL6J-638850.15           4167
# 1018093344100990479-3   C57BL6J-638850.18           4170
# 1018093344101620738-1   C57BL6J-638850.17           4170
# 1018093344102060244-1   C57BL6J-638850.17           3329
# 1017092617201390347     C57BL6J-638850.25           3329
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344101450289-1                   0.528230       C57BL6J-638850
# 1018093344100990479-3                   0.693629       C57BL6J-638850
# 1018093344101620738-1                   0.690500       C57BL6J-638850
# 1018093344102060244-1                   0.609328       C57BL6J-638850
# 1017092617201390347                     0.506157       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344101450289-1  C57BL6J-638850          wt/wt         M  4.884712
# 1018093344100990479-3  C57BL6J-638850          wt/wt         M  6.264717
# 1018093344101620738-1  C57BL6J-638850          wt/wt         M  5.776003
# 1018093344102060244-1  C57BL6J-638850          wt/wt         M  7.081130
# 1017092617201390347    C57BL6J-638850          wt/wt         M  3.815195
#
#                               y    z  ... parcellation_index  \
# cell_label                            ...
# 1018093344101450289-1  3.639677  2.8  ...                810
# 1018093344100990479-3  3.023614  3.4  ...                810
# 1018093344101620738-1  2.652793  3.2  ...                810
# 1018093344102060244-1  2.788188  3.2  ...                818
# 1017092617201390347    3.860187  4.0  ...                818
#
#                       parcellation_organ parcellation_category  \
# cell_label
# 1018093344101450289-1              brain                  grey
# 1018093344100990479-3              brain                  grey
# 1018093344101620738-1              brain                  grey
# 1018093344102060244-1              brain                  grey
# 1017092617201390347                brain                  grey
#
#                       parcellation_division parcellation_structure  \
# cell_label
# 1018093344101450289-1                    MB                     IC
# 1018093344100990479-3                    MB                     IC
# 1018093344101620738-1                    MB                     IC
# 1018093344102060244-1                    MB                     IC
# 1017092617201390347                      MB                     IC
#
#                       parcellation_substructure     Chrm3     Chrm2 Chrm1  \
# cell_label
# 1018093344101450289-1                       ICd  0.078430  0.066101   0.0
# 1018093344100990479-3                       ICd  0.203369  0.370361   0.0
# 1018093344101620738-1                       ICd  0.076294  0.177002   0.0
# 1018093344102060244-1                       ICe  9.710938  7.515625   0.0
# 1017092617201390347                         ICe  9.148438  5.984375   0.0
#
#                           Chrm5
# cell_label
# 1018093344101450289-1  0.000000
# 1018093344100990479-3  0.000000
# 1018093344101620738-1  0.000000
# 1018093344102060244-1  0.000000
# 1017092617201390347    0.410156
#
# [5 rows x 33 columns]

# %%
# (MS) Filtering for specific 'IC' cells and checking unique brain sections
ic_cells = cell_joined[cell_joined["parcellation_structure"] == "IC"] #Change brain region here
ic_cells["brain_section_label"].unique()
ic_cells["brain_section_label"].value_counts() #Choosing section with the most cells
# Out:
# brain_section_label
# C57BL6J-638850.19    815
# C57BL6J-638850.17    710
# C57BL6J-638850.16    631
# C57BL6J-638850.18    619
# C57BL6J-638850.24    527
# C57BL6J-638850.15    240
# C57BL6J-638850.25    184
# C57BL6J-638850.26    110
# C57BL6J-638850.27     15
# C57BL6J-638850.28      3
# Name: count, dtype: int64

# %%
# Filter data by specific brain section
use_section_filter = True # change "False" to "True" if you want to filter for a specific brain section. Leave "False" if you do NOT want to filter.
if use_section_filter:
  cell_table = cell_table[cell_table["brain_section_label"] == "C57BL6J-638850.19"] # "C57BL6J-638850.19" edit brain section filter here (choose most cell count)
else:
  print("Brain section filter not used.")

cell_table
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                       brain_section_label  cluster_alias  \
# cell_label
# 1018093344201690222     C57BL6J-638850.19           3144
# 1018093344101840434-5   C57BL6J-638850.19           3329
# 1018093344101830402-4   C57BL6J-638850.19           3329
# 1018093344201060174     C57BL6J-638850.19           3329
# 1018093344200920518     C57BL6J-638850.19           3330
# ...                                   ...            ...
# 1018093344101830569-3   C57BL6J-638850.19           3562
# 1018093344101220371-3   C57BL6J-638850.19           3563
# 1018093344101220227-4   C57BL6J-638850.19           3568
# 1018093344101520900     C57BL6J-638850.19           3568
# 1018093344101070414-3   C57BL6J-638850.19           3329
#
#                        average_correlation_score feature_matrix_label  \
# cell_label
# 1018093344201690222                     0.533952       C57BL6J-638850
# 1018093344101840434-5                   0.528428       C57BL6J-638850
# 1018093344101830402-4                   0.577765       C57BL6J-638850
# 1018093344201060174                     0.584181       C57BL6J-638850
# 1018093344200920518                     0.512248       C57BL6J-638850
# ...                                          ...                  ...
# 1018093344101830569-3                   0.708108       C57BL6J-638850
# 1018093344101220371-3                   0.640145       C57BL6J-638850
# 1018093344101220227-4                   0.706548       C57BL6J-638850
# 1018093344101520900                     0.725067       C57BL6J-638850
# 1018093344101070414-3                   0.548192       C57BL6J-638850
#
#                           donor_label donor_genotype donor_sex         x  \
# cell_label
# 1018093344201690222    C57BL6J-638850          wt/wt         M  4.415714
# 1018093344101840434-5  C57BL6J-638850          wt/wt         M  3.848218
# 1018093344101830402-4  C57BL6J-638850          wt/wt         M  3.982285
# 1018093344201060174    C57BL6J-638850          wt/wt         M  6.651614
# 1018093344200920518    C57BL6J-638850          wt/wt         M  6.761671
# ...                               ...            ...       ...       ...
# 1018093344101830569-3  C57BL6J-638850          wt/wt         M  3.827300
# 1018093344101220371-3  C57BL6J-638850          wt/wt         M  6.006463
# 1018093344101220227-4  C57BL6J-638850          wt/wt         M  6.078690
# 1018093344101520900    C57BL6J-638850          wt/wt         M  4.809834
# 1018093344101070414-3  C57BL6J-638850          wt/wt         M  6.408738
#
#                               y    z  ... parcellation_index  \
# cell_label                            ...
# 1018093344201690222    3.916725  3.6  ...                810
# 1018093344101840434-5  3.647838  3.6  ...                818
# 1018093344101830402-4  3.319043  3.6  ...                818
# 1018093344201060174    2.751159  3.6  ...                818
# 1018093344200920518    3.471980  3.6  ...                801
# ...                         ...  ...  ...                ...
# 1018093344101830569-3  3.546396  3.6  ...                818
# 1018093344101220371-3  3.070311  3.6  ...                810
# 1018093344101220227-4  3.173500  3.6  ...                810
# 1018093344101520900    3.157964  3.6  ...                810
# 1018093344101070414-3  3.325025  3.6  ...                810
#
#                       parcellation_organ parcellation_category  \
# cell_label
# 1018093344201690222                brain                  grey
# 1018093344101840434-5              brain                  grey
# 1018093344101830402-4              brain                  grey
# 1018093344201060174                brain                  grey
# 1018093344200920518                brain                  grey
# ...                                  ...                   ...
# 1018093344101830569-3              brain                  grey
# 1018093344101220371-3              brain                  grey
# 1018093344101220227-4              brain                  grey
# 1018093344101520900                brain                  grey
# 1018093344101070414-3              brain                  grey
#
#                       parcellation_division parcellation_structure  \
# cell_label
# 1018093344201690222                      MB                     IC
# 1018093344101840434-5                    MB                     IC
# 1018093344101830402-4                    MB                     IC
# 1018093344201060174                      MB                     IC
# 1018093344200920518                      MB                     IC
# ...                                     ...                    ...
# 1018093344101830569-3                    MB                     IC
# 1018093344101220371-3                    MB                     IC
# 1018093344101220227-4                    MB                     IC
# 1018093344101520900                      MB                     IC
# 1018093344101070414-3                    MB                     IC
#
#                       parcellation_substructure     Chrm3     Chrm2     Chrm1  \
# cell_label
# 1018093344201690222                         ICd  8.632812  4.867188  0.000000
# 1018093344101840434-5                       ICe  9.554688  7.656250  0.000000
# 1018093344101830402-4                       ICe  9.695312  7.511719  0.000000
# 1018093344201060174                         ICe  9.109375  7.343750  0.062683
# 1018093344200920518                         ICc  5.273438  4.640625  0.063599
# ...                                         ...       ...       ...       ...
# 1018093344101830569-3                       ICe  3.341797  7.882812  0.691895
# 1018093344101220371-3                       ICd  5.472656  5.214844  0.004566
# 1018093344101220227-4                       ICd  8.429688  6.164062  0.000000
# 1018093344101520900                         ICd  8.609375  6.425781  0.000000
# 1018093344101070414-3                       ICd  9.460938  7.582031  0.000000
#
#                           Chrm5
# cell_label
# 1018093344201690222    0.067505
# 1018093344101840434-5  0.000000
# 1018093344101830402-4  0.000000
# 1018093344201060174    0.048462
# 1018093344200920518    0.148071
# ...                         ...
# 1018093344101830569-3  0.292480
# 1018093344101220371-3  0.871094
# 1018093344101220227-4  0.067566
# 1018093344101520900    0.062439
# 1018093344101070414-3  0.000000
#
# [815 rows x 33 columns]

# %%
# just show gene expression values from previous table for first 5 cells.
# Double check number of cells in table with expected number in ABC Atlas.
gene_table = cell_table[['Chrm1', 'Chrm2', 'Chrm3', 'Chrm5']] # edit genes of interest here
gene_table
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                           Chrm1     Chrm2     Chrm3     Chrm5
# cell_label
# 1018093344201690222    0.000000  4.867188  8.632812  0.067505
# 1018093344101840434-5  0.000000  7.656250  9.554688  0.000000
# 1018093344101830402-4  0.000000  7.511719  9.695312  0.000000
# 1018093344201060174    0.062683  7.343750  9.109375  0.048462
# 1018093344200920518    0.063599  4.640625  5.273438  0.148071
# ...                         ...       ...       ...       ...
# 1018093344101830569-3  0.691895  7.882812  3.341797  0.292480
# 1018093344101220371-3  0.004566  5.214844  5.472656  0.871094
# 1018093344101220227-4  0.000000  6.164062  8.429688  0.067566
# 1018093344101520900    0.000000  6.425781  8.609375  0.062439
# 1018093344101070414-3  0.000000  7.582031  9.460938  0.000000
#
# [815 rows x 4 columns]

# %%
# save gene expression table as csv. saved file will appear in 'files' tab on the left sidebar
gene_table.to_csv('gene_table.csv')

# %%
# create violin plot of gene table

import seaborn as sns

sns.violinplot(data=gene_table)
plt.show()

# %% [markdown]
# # (MS) ADDITIONAL FUNCTIONS

# %%
# 2D spatial plot (Chrm1)
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sc = plt.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    c=cell_table['Chrm1'],
    cmap='viridis',
    s=5
)
plt.colorbar(sc, label='Chrm1 Expression (log2)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Chrm1 Expression in IC (2D Projection)')
plt.show()

# %%
## Trying 2D spatial plot (Chrm2)
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sc = plt.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    c=cell_table['Chrm2'],
    cmap='viridis',
    s=5
)
plt.colorbar(sc, label='Chrm2 Expression (log2)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Chrm2 Expression in IC (2D Projection)')
plt.show()

# %%
## Trying 2D spatial plot (Chrm3)
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sc = plt.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    c=cell_table['Chrm3'],
    cmap='viridis',
    s=5
)
plt.colorbar(sc, label='Chrm3 Expression (log2)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Chrm3 Expression in IC (2D Projection)')
plt.show()

# %%
## Trying 2D spatial plot (Chrm5)
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sc = plt.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    c=cell_table['Chrm5'],
    cmap='viridis',
    s=5
)
plt.colorbar(sc, label='Chrm5 Expression (log2)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Chrm5 Expression in IC (2D Projection)')
plt.show()

# %%
# Trying 3D Spatial Plot (Chrm1)
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(7, 6))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    cell_table['z_reconstructed'],
    c=cell_table['Chrm1'],
    cmap='plasma',
    s=5
)
fig.colorbar(p, label='Chrm1 Expression (log2)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Chrm1 Spatial Expression in IC (3D projection)')
plt.show()

# %%
# Trying 3D Spatial Plot (Chrm2)
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(7, 6))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    cell_table['z_reconstructed'],
    c=cell_table['Chrm2'],
    cmap='plasma',
    s=5
)
fig.colorbar(p, label='Chrm2 Expression (log2)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Chrm2 Spatial Expression in IC (3D projection)')
plt.show()

# %%
# Trying 3D Spatial Plot (Chrm3)
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(7, 6))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    cell_table['z_reconstructed'],
    c=cell_table['Chrm3'],
    cmap='plasma',
    s=5
)
fig.colorbar(p, label='Chrm3 Expression (log2)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Chrm3 Spatial Expression in IC (3D projection)')
plt.show()

# %%
# Trying 3D Spatial Plot (Chrm5)
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(7, 6))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(
    cell_table['x_reconstructed'],
    cell_table['y_reconstructed'],
    cell_table['z_reconstructed'],
    c=cell_table['Chrm5'],
    cmap='plasma',
    s=5
)
fig.colorbar(p, label='Chrm5 Expression (log2)')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Chrm5 Spatial Expression in IC (3D projection)')
plt.show()

# %%
# Co-expression (Pairplot)
import seaborn as sns
import matplotlib.pyplot as plt

# Select the genes to compare
genes_of_interest = ['Chrm1', 'Chrm2', 'Chrm3', 'Chrm5']
pairplot_data = gene_table[genes_of_interest]   # gene_table came from earlier steps

# Make a Seaborn pairplot:   diagonal = histograms
#                            off‑diagonal = scatterplots

sns.pairplot(pairplot_data,
             diag_kind='hist',          # histogram on the diagonal
             corner=False)              # show upper‑right plots too
plt.suptitle("Pairwise Co‑Expression of Muscarinic Genes in IC",
             y=1.02)                    # move title up a bit
plt.show()

# %%
# Co-Expression (Correlation heat-map)
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the Pearson correlation matrix for the same 4 genes
corr = gene_table[genes_of_interest].corr(method='pearson')

# Plot the correlation matrix as a heat‑map
plt.figure(figsize=(5,4))
sns.heatmap(corr,
            annot=True,    # write the numbers on the squares
            vmin=-1, vmax=1,
            cmap='coolwarm')
plt.title("Correlation Matrix of Muscarinic Gene Expression in IC")
plt.tight_layout()
plt.show()

# %%
# Required libraries
import pandas as pd
import umap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Step 1: Define region and genes of interest
target_region = 'IC'  # Use exact name from your dataset
genes_of_interest = ['Chrm1', 'Chrm2', 'Chrm3', 'Chrm5']

# Step 2: Filter cells for the IC
ic_cells = cell_table[cell_table['parcellation_structure'] == target_region].copy()
print(f"Number of IC cells: {ic_cells.shape[0]}")

# Step 3: Check which genes are available
available_genes = [g for g in genes_of_interest if g in ic_cells.columns]
missing_genes = [g for g in genes_of_interest if g not in ic_cells.columns]

if missing_genes:
    print(f"Missing genes: {missing_genes}")
else:
    print("All genes available.")

# Step 4: Extract expression data and normalize
gene_data = ic_cells[available_genes].fillna(0)
gene_data_scaled = StandardScaler().fit_transform(gene_data)

# Step 5: Run UMAP
reducer = umap.UMAP(n_components=2, random_state=42)
umap_embedding = reducer.fit_transform(gene_data_scaled)

# Step 6: Prepare UMAP DataFrame
umap_df = pd.DataFrame(umap_embedding, columns=['UMAP1', 'UMAP2'])
umap_df[available_genes] = gene_data.values  # attach gene expression

# Step 7: Plot co-expression (mean) across all 4 genes
umap_df['mean_expression'] = umap_df[available_genes].mean(axis=1)

# Step 8: Plot UMAP with color representing co-expression
plt.figure(figsize=(10, 8))
scatter = plt.scatter(
    umap_df['UMAP1'], umap_df['UMAP2'],
    c=umap_df['mean_expression'],
    cmap='viridis',
    s=10,
    alpha=0.7
)
plt.title("2D UMAP of Chrm1, Chrm2, Chrm3, Chrm5 Expression in Inferior Colliculus")
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
cbar = plt.colorbar(scatter)
cbar.set_label("Mean Expression (Z-scored)")

plt.tight_layout()
plt.show()
# Out:
# Number of IC cells: 815
# All genes available.

# %%
# UMAP (3D)
import umap
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Step 1: Prepare data — use expression of Chrna7 and Chrm1 in CA1
gene_data = ca1_cells[['Chrm1', 'Chrm2', 'Chrm3', 'Chrm5']].copy()

# Step 2: Run UMAP in 3 dimensions
reducer = umap.UMAP(n_components=3, random_state=42)
embedding_3d = reducer.fit_transform(gene_data)

# Step 3: Convert to DataFrame for easier plotting
umap_3d_df = pd.DataFrame(embedding_3d, columns=['UMAP1', 'UMAP2', 'UMAP3'])
umap_3d_df['Chrm1'] = gene_data['Chrm1'].values
umap_3d_df['Chrm2'] = gene_data['Chrm2'].values
umap_3d_df['Chrm3'] = gene_data['Chrm3'].values
umap_3d_df['Chrm5'] = gene_data['Chrm5'].values

# Step 4: Plot 3D UMAP, color by Chrna7 expression
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Use Chrm1 expression to color points
scatter = ax.scatter(
    umap_3d_df['UMAP1'],
    umap_3d_df['UMAP2'],
    umap_3d_df['UMAP3'],
    c=umap_3d_df['Chrm1'],
    cmap='viridis',
    s=15,
    alpha=0.8
)

# Step 5: Add labels and color bar
ax.set_xlabel('UMAP1')
ax.set_ylabel('UMAP2')
ax.set_zlabel('UMAP3')
ax.set_title('3D UMAP of IC Cells Colored by Chrm1 Expression')
fig.colorbar(scatter, ax=ax, label='Chrm1 Expression')

plt.tight_layout()
plt.show()
